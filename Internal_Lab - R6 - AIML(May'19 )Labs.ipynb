# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# !pip install -U tensorflow --quiet
# %tensorflow_version 2
# Out:
#      |████████████████████████████████| 86.3MB 62.3MB/s
#      |████████████████████████████████| 3.8MB 32.1MB/s
#      |████████████████████████████████| 450kB 41.8MB/s
# `%tensorflow_version` only switches the major version: `1.x` or `2.x`.
# You set: `2`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-rc2

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from sklearn import datasets

# %%
iris=datasets.load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
X=iris.data
y=iris.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,stratify=y,random_state=55)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test= tf.keras.utils.to_categorical(y_test, num_classes=3)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
model=tf.keras.models.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
model.add(tf.keras.layers.Dense(3, input_shape=(4,), activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
model.fit(X_train, y_train, 
          validation_data=(X_test, y_test), 
          epochs=100)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/100
# 112/112 [==============================] - 0s 352us/sample - loss: 0.3481 - accuracy: 0.9554 - val_loss: 0.3306 - val_accuracy: 0.9474
# Epoch 2/100
# 112/112 [==============================] - 0s 287us/sample - loss: 0.3447 - accuracy: 0.9464 - val_loss: 0.3300 - val_accuracy: 0.9474
# Epoch 3/100
# 112/112 [==============================] - 0s 276us/sample - loss: 0.3429 - accuracy: 0.9554 - val_loss: 0.3296 - val_accuracy: 0.9474
# Epoch 4/100
# 112/112 [==============================] - 0s 291us/sample - loss: 0.3423 - accuracy: 0.9464 - val_loss: 0.3291 - val_accuracy: 0.9474
# Epoch 5/100
# 112/112 [==============================] - 0s 330us/sample - loss: 0.3422 - accuracy: 0.9643 - val_loss: 0.3297 - val_accuracy: 0.9737
# Epoch 6/100
# 112/112 [==============================] - 0s 322us/sample - loss: 0.3432 - accuracy: 0.9464 - val_loss: 0.3282 - val_accuracy: 0.9474
# Epoch 7/100
# 112/112 [==============================] - 0s 244us/sample - loss: 0.3417 - accuracy: 0.9554 - val_loss: 0.3275 - val_accuracy: 0.9474
# Epoch 8/100
# 112/112 [==============================] - 0s 277us/sample - loss: 0.3436 - accuracy: 0.9375 - val_loss: 0.3289 - val_accuracy: 0.9737
# Epoch 9/100
# 112/112 [==============================] - 0s 273us/sample - loss: 0.3440 - accuracy: 0.9464 - val_loss: 0.3275 - val_accuracy: 0.9737
# Epoch 10/100
# 112/112 [==============================] - 0s 283us/sample - loss: 0.3405 - accuracy: 0.9464 - val_loss: 0.3262 - val_accuracy: 0.9474
# Epoch 11/100
# 112/112 [==============================] - 0s 270us/sample - loss: 0.3398 - accuracy: 0.9643 - val_loss: 0.3260 - val_accuracy: 0.9474
# Epoch 12/100
# 112/112 [==============================] - 0s 329us/sample - loss: 0.3406 - accuracy: 0.9643 - val_loss: 0.3252 - val_accuracy: 0.9474
# Epoch 13/100
# 112/112 [==============================] - 0s 337us/sample - loss: 0.3384 - accuracy: 0.9464 - val_loss: 0.3248 - val_accuracy: 0.9474
# Epoch 14/100
# 112/112 [==============================] - 0s 279us/sample - loss: 0.3375 - accuracy: 0.9732 - val_loss: 0.3244 - val_accuracy: 0.9474
# Epoch 15/100
# 112/112 [==============================] - 0s 289us/sample - loss: 0.3373 - accuracy: 0.9464 - val_loss: 0.3239 - val_accuracy: 0.9474
# Epoch 16/100
# 112/112 [==============================] - 0s 294us/sample - loss: 0.3369 - accuracy: 0.9643 - val_loss: 0.3234 - val_accuracy: 0.9474
# Epoch 17/100
# 112/112 [==============================] - 0s 291us/sample - loss: 0.3391 - accuracy: 0.9554 - val_loss: 0.3247 - val_accuracy: 0.9737
# Epoch 18/100
# 112/112 [==============================] - 0s 275us/sample - loss: 0.3423 - accuracy: 0.9554 - val_loss: 0.3233 - val_accuracy: 0.9737
# Epoch 19/100
# 112/112 [==============================] - 0s 314us/sample - loss: 0.3373 - accuracy: 0.9375 - val_loss: 0.3230 - val_accuracy: 0.9737
# Epoch 20/100
# 112/112 [==============================] - 0s 292us/sample - loss: 0.3367 - accuracy: 0.9554 - val_loss: 0.3225 - val_accuracy: 0.9737
# Epoch 21/100
# 112/112 [==============================] - 0s 294us/sample - loss: 0.3384 - accuracy: 0.9554 - val_loss: 0.3238 - val_accuracy: 0.9737
# Epoch 22/100
# 112/112 [==============================] - 0s 276us/sample - loss: 0.3363 - accuracy: 0.9375 - val_loss: 0.3208 - val_accuracy: 0.9474
# Epoch 23/100
# 112/112 [==============================] - 0s 260us/sample - loss: 0.3340 - accuracy: 0.9643 - val_loss: 0.3202 - val_accuracy: 0.9474
# Epoch 24/100
# 112/112 [==============================] - 0s 286us/sample - loss: 0.3343 - accuracy: 0.9464 - val_loss: 0.3211 - val_accuracy: 0.9737
# Epoch 25/100
# 112/112 [==============================] - 0s 318us/sample - loss: 0.3335 - accuracy: 0.9732 - val_loss: 0.3198 - val_accuracy: 0.9474
# Epoch 26/100
# 112/112 [==============================] - 0s 283us/sample - loss: 0.3336 - accuracy: 0.9732 - val_loss: 0.3192 - val_accuracy: 0.9474
# Epoch 27/100
# 112/112 [==============================] - 0s 271us/sample - loss: 0.3333 - accuracy: 0.9732 - val_loss: 0.3184 - val_accuracy: 0.9474
# Epoch 28/100
# 112/112 [==============================] - 0s 269us/sample - loss: 0.3324 - accuracy: 0.9643 - val_loss: 0.3182 - val_accuracy: 0.9474
# Epoch 29/100
# 112/112 [==============================] - 0s 283us/sample - loss: 0.3324 - accuracy: 0.9554 - val_loss: 0.3179 - val_accuracy: 0.9474
# Epoch 30/100
# 112/112 [==============================] - 0s 290us/sample - loss: 0.3326 - accuracy: 0.9643 - val_loss: 0.3173 - val_accuracy: 0.9474
# Epoch 31/100
# 112/112 [==============================] - 0s 308us/sample - loss: 0.3333 - accuracy: 0.9643 - val_loss: 0.3169 - val_accuracy: 0.9474
# Epoch 32/100
# 112/112 [==============================] - 0s 293us/sample - loss: 0.3304 - accuracy: 0.9643 - val_loss: 0.3170 - val_accuracy: 0.9474
# Epoch 33/100
# 112/112 [==============================] - 0s 264us/sample - loss: 0.3315 - accuracy: 0.9643 - val_loss: 0.3158 - val_accuracy: 0.9474
# Epoch 34/100
# 112/112 [==============================] - 0s 284us/sample - loss: 0.3297 - accuracy: 0.9464 - val_loss: 0.3153 - val_accuracy: 0.9474
# Epoch 35/100
# 112/112 [==============================] - 0s 314us/sample - loss: 0.3330 - accuracy: 0.9643 - val_loss: 0.3155 - val_accuracy: 0.9737
# Epoch 36/100
# 112/112 [==============================] - 0s 280us/sample - loss: 0.3306 - accuracy: 0.9464 - val_loss: 0.3145 - val_accuracy: 0.9474
# Epoch 37/100
# 112/112 [==============================] - 0s 299us/sample - loss: 0.3288 - accuracy: 0.9643 - val_loss: 0.3140 - val_accuracy: 0.9474
# Epoch 38/100
# 112/112 [==============================] - 0s 276us/sample - loss: 0.3302 - accuracy: 0.9464 - val_loss: 0.3141 - val_accuracy: 0.9474
# Epoch 39/100
# 112/112 [==============================] - 0s 272us/sample - loss: 0.3283 - accuracy: 0.9732 - val_loss: 0.3132 - val_accuracy: 0.9474
# Epoch 40/100
# 112/112 [==============================] - 0s 289us/sample - loss: 0.3281 - accuracy: 0.9464 - val_loss: 0.3128 - val_accuracy: 0.9474
# Epoch 41/100
# 112/112 [==============================] - 0s 310us/sample - loss: 0.3269 - accuracy: 0.9732 - val_loss: 0.3124 - val_accuracy: 0.9474
# Epoch 42/100
# 112/112 [==============================] - 0s 291us/sample - loss: 0.3274 - accuracy: 0.9554 - val_loss: 0.3119 - val_accuracy: 0.9474
# Epoch 43/100
# 112/112 [==============================] - 0s 334us/sample - loss: 0.3283 - accuracy: 0.9643 - val_loss: 0.3115 - val_accuracy: 0.9474
# Epoch 44/100
# 112/112 [==============================] - 0s 293us/sample - loss: 0.3267 - accuracy: 0.9464 - val_loss: 0.3120 - val_accuracy: 0.9737
# Epoch 45/100
# 112/112 [==============================] - 0s 277us/sample - loss: 0.3270 - accuracy: 0.9464 - val_loss: 0.3108 - val_accuracy: 0.9474
# Epoch 46/100
# 112/112 [==============================] - 0s 301us/sample - loss: 0.3260 - accuracy: 0.9464 - val_loss: 0.3104 - val_accuracy: 0.9474
# Epoch 47/100
# 112/112 [==============================] - 0s 279us/sample - loss: 0.3244 - accuracy: 0.9643 - val_loss: 0.3099 - val_accuracy: 0.9474
# Epoch 48/100
# 112/112 [==============================] - 0s 265us/sample - loss: 0.3247 - accuracy: 0.9554 - val_loss: 0.3101 - val_accuracy: 0.9474
# Epoch 49/100
# 112/112 [==============================] - 0s 310us/sample - loss: 0.3249 - accuracy: 0.9643 - val_loss: 0.3094 - val_accuracy: 0.9474
# Epoch 50/100
# 112/112 [==============================] - 0s 267us/sample - loss: 0.3234 - accuracy: 0.9732 - val_loss: 0.3090 - val_accuracy: 0.9474
# Epoch 51/100
# 112/112 [==============================] - 0s 273us/sample - loss: 0.3241 - accuracy: 0.9643 - val_loss: 0.3082 - val_accuracy: 0.9474
# Epoch 52/100
# 112/112 [==============================] - 0s 297us/sample - loss: 0.3252 - accuracy: 0.9554 - val_loss: 0.3112 - val_accuracy: 0.9737
# Epoch 53/100
# 112/112 [==============================] - 0s 273us/sample - loss: 0.3237 - accuracy: 0.9643 - val_loss: 0.3079 - val_accuracy: 0.9474
# Epoch 54/100
# 112/112 [==============================] - 0s 280us/sample - loss: 0.3244 - accuracy: 0.9643 - val_loss: 0.3076 - val_accuracy: 0.9474
# Epoch 55/100
# 112/112 [==============================] - 0s 285us/sample - loss: 0.3223 - accuracy: 0.9732 - val_loss: 0.3066 - val_accuracy: 0.9474
# Epoch 56/100
# 112/112 [==============================] - 0s 311us/sample - loss: 0.3217 - accuracy: 0.9554 - val_loss: 0.3067 - val_accuracy: 0.9474
# Epoch 57/100
# 112/112 [==============================] - 0s 266us/sample - loss: 0.3224 - accuracy: 0.9732 - val_loss: 0.3058 - val_accuracy: 0.9474
# Epoch 58/100
# 112/112 [==============================] - 0s 260us/sample - loss: 0.3214 - accuracy: 0.9643 - val_loss: 0.3055 - val_accuracy: 0.9474
# Epoch 59/100
# 112/112 [==============================] - 0s 275us/sample - loss: 0.3234 - accuracy: 0.9464 - val_loss: 0.3053 - val_accuracy: 0.9474
# Epoch 60/100
# 112/112 [==============================] - 0s 268us/sample - loss: 0.3213 - accuracy: 0.9643 - val_loss: 0.3066 - val_accuracy: 0.9737
# Epoch 61/100
# 112/112 [==============================] - 0s 352us/sample - loss: 0.3210 - accuracy: 0.9732 - val_loss: 0.3049 - val_accuracy: 0.9737
# Epoch 62/100
# 112/112 [==============================] - 0s 308us/sample - loss: 0.3230 - accuracy: 0.9643 - val_loss: 0.3040 - val_accuracy: 0.9474
# Epoch 63/100
# 112/112 [==============================] - 0s 313us/sample - loss: 0.3190 - accuracy: 0.9554 - val_loss: 0.3035 - val_accuracy: 0.9474
# Epoch 64/100
# 112/112 [==============================] - 0s 339us/sample - loss: 0.3219 - accuracy: 0.9554 - val_loss: 0.3030 - val_accuracy: 0.9474
# Epoch 65/100
# 112/112 [==============================] - 0s 317us/sample - loss: 0.3198 - accuracy: 0.9554 - val_loss: 0.3026 - val_accuracy: 0.9474
# Epoch 66/100
# 112/112 [==============================] - 0s 323us/sample - loss: 0.3187 - accuracy: 0.9554 - val_loss: 0.3022 - val_accuracy: 0.9474
# Epoch 67/100
# 112/112 [==============================] - 0s 316us/sample - loss: 0.3181 - accuracy: 0.9554 - val_loss: 0.3020 - val_accuracy: 0.9474
# Epoch 68/100
# 112/112 [==============================] - 0s 373us/sample - loss: 0.3167 - accuracy: 0.9643 - val_loss: 0.3018 - val_accuracy: 0.9474
# Epoch 69/100
# 112/112 [==============================] - 0s 291us/sample - loss: 0.3183 - accuracy: 0.9643 - val_loss: 0.3014 - val_accuracy: 0.9474
# Epoch 70/100
# 112/112 [==============================] - 0s 303us/sample - loss: 0.3200 - accuracy: 0.9464 - val_loss: 0.3008 - val_accuracy: 0.9474
# Epoch 71/100
# 112/112 [==============================] - 0s 282us/sample - loss: 0.3161 - accuracy: 0.9643 - val_loss: 0.3006 - val_accuracy: 0.9474
# Epoch 72/100
# 112/112 [==============================] - 0s 286us/sample - loss: 0.3173 - accuracy: 0.9554 - val_loss: 0.3002 - val_accuracy: 0.9474
# Epoch 73/100
# 112/112 [==============================] - 0s 302us/sample - loss: 0.3150 - accuracy: 0.9643 - val_loss: 0.2998 - val_accuracy: 0.9474
# Epoch 74/100
# 112/112 [==============================] - 0s 296us/sample - loss: 0.3147 - accuracy: 0.9643 - val_loss: 0.2997 - val_accuracy: 0.9474
# Epoch 75/100
# 112/112 [==============================] - 0s 306us/sample - loss: 0.3152 - accuracy: 0.9643 - val_loss: 0.3000 - val_accuracy: 0.9737
# Epoch 76/100
# 112/112 [==============================] - 0s 295us/sample - loss: 0.3187 - accuracy: 0.9464 - val_loss: 0.2984 - val_accuracy: 0.9474
# Epoch 77/100
# 112/112 [==============================] - 0s 306us/sample - loss: 0.3171 - accuracy: 0.9554 - val_loss: 0.2981 - val_accuracy: 0.9474
# Epoch 78/100
# 112/112 [==============================] - 0s 286us/sample - loss: 0.3138 - accuracy: 0.9464 - val_loss: 0.2976 - val_accuracy: 0.9474
# Epoch 79/100
# 112/112 [==============================] - 0s 296us/sample - loss: 0.3145 - accuracy: 0.9464 - val_loss: 0.2973 - val_accuracy: 0.9474
# Epoch 80/100
# 112/112 [==============================] - 0s 274us/sample - loss: 0.3145 - accuracy: 0.9643 - val_loss: 0.2977 - val_accuracy: 0.9737
# Epoch 81/100
# 112/112 [==============================] - 0s 293us/sample - loss: 0.3131 - accuracy: 0.9732 - val_loss: 0.2967 - val_accuracy: 0.9474
# Epoch 82/100
# 112/112 [==============================] - 0s 267us/sample - loss: 0.3128 - accuracy: 0.9643 - val_loss: 0.2974 - val_accuracy: 0.9737
# Epoch 83/100
# 112/112 [==============================] - 0s 292us/sample - loss: 0.3129 - accuracy: 0.9643 - val_loss: 0.2960 - val_accuracy: 0.9474
# Epoch 84/100
# 112/112 [==============================] - 0s 272us/sample - loss: 0.3116 - accuracy: 0.9554 - val_loss: 0.2959 - val_accuracy: 0.9474
# Epoch 85/100
# 112/112 [==============================] - 0s 273us/sample - loss: 0.3137 - accuracy: 0.9643 - val_loss: 0.2952 - val_accuracy: 0.9474
# Epoch 86/100
# 112/112 [==============================] - 0s 290us/sample - loss: 0.3136 - accuracy: 0.9643 - val_loss: 0.2947 - val_accuracy: 0.9474
# Epoch 87/100
# 112/112 [==============================] - 0s 310us/sample - loss: 0.3116 - accuracy: 0.9643 - val_loss: 0.2947 - val_accuracy: 0.9737
# Epoch 88/100
# 112/112 [==============================] - 0s 291us/sample - loss: 0.3107 - accuracy: 0.9554 - val_loss: 0.2940 - val_accuracy: 0.9474
# Epoch 89/100
# 112/112 [==============================] - 0s 326us/sample - loss: 0.3112 - accuracy: 0.9554 - val_loss: 0.2937 - val_accuracy: 0.9474
# Epoch 90/100
# 112/112 [==============================] - 0s 272us/sample - loss: 0.3099 - accuracy: 0.9643 - val_loss: 0.2933 - val_accuracy: 0.9474
# Epoch 91/100
# 112/112 [==============================] - 0s 319us/sample - loss: 0.3091 - accuracy: 0.9554 - val_loss: 0.2929 - val_accuracy: 0.9474
# Epoch 92/100
# 112/112 [==============================] - 0s 303us/sample - loss: 0.3095 - accuracy: 0.9643 - val_loss: 0.2926 - val_accuracy: 0.9474
# Epoch 93/100
# 112/112 [==============================] - 0s 305us/sample - loss: 0.3086 - accuracy: 0.9643 - val_loss: 0.2926 - val_accuracy: 0.9474
# Epoch 94/100
# 112/112 [==============================] - 0s 318us/sample - loss: 0.3080 - accuracy: 0.9732 - val_loss: 0.2918 - val_accuracy: 0.9474
# Epoch 95/100
# 112/112 [==============================] - 0s 293us/sample - loss: 0.3083 - accuracy: 0.9554 - val_loss: 0.2924 - val_accuracy: 0.9737
# Epoch 96/100
# 112/112 [==============================] - 0s 289us/sample - loss: 0.3088 - accuracy: 0.9643 - val_loss: 0.2916 - val_accuracy: 0.9737
# Epoch 97/100
# 112/112 [==============================] - 0s 261us/sample - loss: 0.3096 - accuracy: 0.9643 - val_loss: 0.2908 - val_accuracy: 0.9474
# Epoch 98/100
# 112/112 [==============================] - 0s 275us/sample - loss: 0.3098 - accuracy: 0.9464 - val_loss: 0.2919 - val_accuracy: 0.9737
# Epoch 99/100
# 112/112 [==============================] - 0s 272us/sample - loss: 0.3087 - accuracy: 0.9464 - val_loss: 0.2901 - val_accuracy: 0.9474
# Epoch 100/100
# 112/112 [==============================] - 0s 296us/sample - loss: 0.3068 - accuracy: 0.9643 - val_loss: 0.2901 - val_accuracy: 0.9737

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
import numpy as np
input_data = np.expand_dims(X_test[13], axis=0)

# %%
pred = model.predict(input_data)

# %%
np.argmax(pred)
# Out:
# 2

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
np.argmax(y_test[13])
# Out:
# 2

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
#%tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
#import tensorflow as tf
#print(tf.__version__)

# %% [markdown]
# ### Set random seed

# %%
#tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6eb2a794-9466-410e-9c9b-890aa3d3386a" name="files[]" multiple disabled />
#      <output id="result-6eb2a794-9466-410e-9c9b-890aa3d3386a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
import pandas as pd
df=pd.read_csv("prices.csv")

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
df1=df.iloc[:1000,]

# %%
df1.shape
# Out:
# (1000, 7)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
df1.head()
# Out:
#                   date symbol        open  ...         low        high     volume
# 0  2016-01-05 00:00:00   WLTW  123.430000  ...  122.309998  126.250000  2163600.0
# 1  2016-01-06 00:00:00   WLTW  125.239998  ...  119.940002  125.540001  2386400.0
# 2  2016-01-07 00:00:00   WLTW  116.379997  ...  114.930000  119.739998  2489500.0
# 3  2016-01-08 00:00:00   WLTW  115.480003  ...  113.500000  117.440002  2006300.0
# 4  2016-01-11 00:00:00   WLTW  117.010002  ...  114.089996  117.330002  1408600.0
#
# [5 rows x 7 columns]

# %%
df1=df1.drop('date',axis=1)

# %%
df1=df1.drop('symbol',axis=1)

# %%
df1.head()
# Out:
#          open       close         low        high     volume
# 0  123.430000  125.839996  122.309998  126.250000  2163600.0
# 1  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2  116.379997  114.949997  114.930000  119.739998  2489500.0
# 3  115.480003  116.620003  113.500000  117.440002  2006300.0
# 4  117.010002  114.970001  114.089996  117.330002  1408600.0

# %%
df1.volume=df1.volume/1000000

# %%
df1.head()
# Out:
#          open       close         low        high  volume
# 0  123.430000  125.839996  122.309998  126.250000  2.1636
# 1  125.239998  119.980003  119.940002  125.540001  2.3864
# 2  116.379997  114.949997  114.930000  119.739998  2.4895
# 3  115.480003  116.620003  113.500000  117.440002  2.0063
# 4  117.010002  114.970001  114.089996  117.330002  1.4086

# %%
X=np.array(df1.iloc[:,0:4])

# %%
y=np.array(df1.iloc[:,4])

# %%
X
# Out:
# array([[123.43    , 125.839996, 122.309998, 126.25    ],
#        [125.239998, 119.980003, 119.940002, 125.540001],
#        [116.379997, 114.949997, 114.93    , 119.739998],
#        ...,
#        [ 28.32    ,  28.77    ,  28.01    ,  28.809999],
#        [ 44.      ,  44.799999,  43.75    ,  44.810001],
#        [ 36.080002,  37.139999,  36.009998,  37.23    ]])

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X=X.astype('float32')
y=y.astype('float32')

# %%
# Out:
# dtype('O')

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X= tf.math.l2_normalize(X)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
w = tf.zeros(shape=(4,1))
b = tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
def prediction(x, w, b):
    
    xw_matmul = tf.matmul(x, w)
    u = tf.add(xw_matmul, b)
    
    return u

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
def loss(y_actual, y_predicted):
    
    diff = y_actual - y_predicted
    sqr = tf.square(diff)
    avg = tf.reduce_mean(sqr)
    
    return avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(x, y_actual, w, b, learning_rate=0.01):
    
   
    with tf.GradientTape() as t:
        
        t.watch([w,b])
        
        current_prediction = prediction(x, w, b)
        current_loss = loss(y_actual, current_prediction)
    
    
    dw, db = t.gradient(current_loss,[w, b])
    
    
    w = w - learning_rate*dw
    b = b - learning_rate*db
    
    return w, b

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for i in range(100):
    
    w, b = train(X, y, w, b, learning_rate=0.01)
    print('Current Loss on iteration', i, 
          loss(y, prediction(X, w, b)).numpy())
# Out:
# Current Loss on iteration 0 236.16776
# Current Loss on iteration 1 235.09312
# Current Loss on iteration 2 234.06105
# Current Loss on iteration 3 233.0699
# Current Loss on iteration 4 232.11801
# Current Loss on iteration 5 231.20383
# Current Loss on iteration 6 230.32588
# Current Loss on iteration 7 229.48273
# Current Loss on iteration 8 228.67296
# Current Loss on iteration 9 227.8953
# Current Loss on iteration 10 227.14842
# Current Loss on iteration 11 226.43114
# Current Loss on iteration 12 225.74234
# Current Loss on iteration 13 225.08076
# Current Loss on iteration 14 224.44542
# Current Loss on iteration 15 223.83525
# Current Loss on iteration 16 223.24927
# Current Loss on iteration 17 222.68645
# Current Loss on iteration 18 222.146
# Current Loss on iteration 19 221.62692
# Current Loss on iteration 20 221.12845
# Current Loss on iteration 21 220.64972
# Current Loss on iteration 22 220.18996
# Current Loss on iteration 23 219.74837
# Current Loss on iteration 24 219.32433
# Current Loss on iteration 25 218.91707
# Current Loss on iteration 26 218.52594
# Current Loss on iteration 27 218.15028
# Current Loss on iteration 28 217.78957
# Current Loss on iteration 29 217.44312
# Current Loss on iteration 30 217.11038
# Current Loss on iteration 31 216.79086
# Current Loss on iteration 32 216.48398
# Current Loss on iteration 33 216.18927
# Current Loss on iteration 34 215.9062
# Current Loss on iteration 35 215.63438
# Current Loss on iteration 36 215.37332
# Current Loss on iteration 37 215.12262
# Current Loss on iteration 38 214.88182
# Current Loss on iteration 39 214.6506
# Current Loss on iteration 40 214.42853
# Current Loss on iteration 41 214.21524
# Current Loss on iteration 42 214.01044
# Current Loss on iteration 43 213.8137
# Current Loss on iteration 44 213.6248
# Current Loss on iteration 45 213.44337
# Current Loss on iteration 46 213.26913
# Current Loss on iteration 47 213.10176
# Current Loss on iteration 48 212.94109
# Current Loss on iteration 49 212.78674
# Current Loss on iteration 50 212.63852
# Current Loss on iteration 51 212.49617
# Current Loss on iteration 52 212.35944
# Current Loss on iteration 53 212.22815
# Current Loss on iteration 54 212.10207
# Current Loss on iteration 55 211.98096
# Current Loss on iteration 56 211.86464
# Current Loss on iteration 57 211.75299
# Current Loss on iteration 58 211.64569
# Current Loss on iteration 59 211.54271
# Current Loss on iteration 60 211.44376
# Current Loss on iteration 61 211.34872
# Current Loss on iteration 62 211.2575
# Current Loss on iteration 63 211.16988
# Current Loss on iteration 64 211.0857
# Current Loss on iteration 65 211.00488
# Current Loss on iteration 66 210.92723
# Current Loss on iteration 67 210.85272
# Current Loss on iteration 68 210.7811
# Current Loss on iteration 69 210.71236
# Current Loss on iteration 70 210.64632
# Current Loss on iteration 71 210.5829
# Current Loss on iteration 72 210.52199
# Current Loss on iteration 73 210.46352
# Current Loss on iteration 74 210.40733
# Current Loss on iteration 75 210.35338
# Current Loss on iteration 76 210.30156
# Current Loss on iteration 77 210.25183
# Current Loss on iteration 78 210.20403
# Current Loss on iteration 79 210.15813
# Current Loss on iteration 80 210.11407
# Current Loss on iteration 81 210.07172
# Current Loss on iteration 82 210.03108
# Current Loss on iteration 83 209.99205
# Current Loss on iteration 84 209.95454
# Current Loss on iteration 85 209.91853
# Current Loss on iteration 86 209.88396
# Current Loss on iteration 87 209.85075
# Current Loss on iteration 88 209.81883
# Current Loss on iteration 89 209.78822
# Current Loss on iteration 90 209.75882
# Current Loss on iteration 91 209.73055
# Current Loss on iteration 92 209.70343
# Current Loss on iteration 93 209.67735
# Current Loss on iteration 94 209.65233
# Current Loss on iteration 95 209.62828
# Current Loss on iteration 96 209.60522
# Current Loss on iteration 97 209.58304
# Current Loss on iteration 98 209.56177
# Current Loss on iteration 99 209.5413

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
print('Weights:\n', w.numpy())
# Out:
# Weights:
#  [[0.0547828 ]
#  [0.0548819 ]
#  [0.05422734]
#  [0.05533116]]

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
print('Bias:\n',b.numpy())
# Out:
# Bias:
#  [4.607657]
