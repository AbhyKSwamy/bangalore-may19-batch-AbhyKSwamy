# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# !pip install -U tensorflow --quiet
# Out:
#      |████████████████████████████████| 86.3MB 140kB/s
#      |████████████████████████████████| 3.8MB 29.6MB/s
#      |████████████████████████████████| 450kB 45.5MB/s
#      |████████████████████████████████| 81kB 10.6MB/s
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.1 which is incompatible.

# %%
import tensorflow as tf
print (tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from tensorflow.keras.datasets import fashion_mnist 
(x_train,y_train),(x_test,y_test)=fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
import keras
y_test=keras.utils.to_categorical(y_test,num_classes=10)
y_train=keras.utils.to_categorical(y_train,num_classes=10)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
model.add(tf.keras.layers.Dense(200))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dense(100))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(tf.keras.layers.Dense(10))
model.add(tf.keras.layers.Activation('softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# activation (Activation)      (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_1 (Activation)    (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# activation_2 (Activation)    (None, 100)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 221,446
# Trainable params: 219,878
# Non-trainable params: 1,568
# _________________________________________________________________

# %%
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=100,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# 60000/60000 [==============================] - 12s 202us/sample - loss: 0.5083 - accuracy: 0.8208 - val_loss: 0.4002 - val_accuracy: 0.8528
# Epoch 2/100
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.3884 - accuracy: 0.8605 - val_loss: 0.3851 - val_accuracy: 0.8583
# Epoch 3/100
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.3495 - accuracy: 0.8740 - val_loss: 0.3608 - val_accuracy: 0.8731
# Epoch 4/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.3245 - accuracy: 0.8823 - val_loss: 0.3598 - val_accuracy: 0.8723
# Epoch 5/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.3071 - accuracy: 0.8864 - val_loss: 0.3707 - val_accuracy: 0.8699
# Epoch 6/100
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.2919 - accuracy: 0.8922 - val_loss: 0.3549 - val_accuracy: 0.8828
# Epoch 7/100
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.2754 - accuracy: 0.8979 - val_loss: 0.3432 - val_accuracy: 0.8861
# Epoch 8/100
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.2622 - accuracy: 0.9007 - val_loss: 0.3503 - val_accuracy: 0.8831
# Epoch 9/100
# 60000/60000 [==============================] - 11s 189us/sample - loss: 0.2478 - accuracy: 0.9065 - val_loss: 0.3654 - val_accuracy: 0.8853
# Epoch 10/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.2428 - accuracy: 0.9081 - val_loss: 0.3721 - val_accuracy: 0.8829
# Epoch 11/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.2319 - accuracy: 0.9140 - val_loss: 0.3765 - val_accuracy: 0.8877
# Epoch 12/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.2235 - accuracy: 0.9164 - val_loss: 0.3690 - val_accuracy: 0.8901
# Epoch 13/100
# 60000/60000 [==============================] - 11s 184us/sample - loss: 0.2146 - accuracy: 0.9185 - val_loss: 0.3808 - val_accuracy: 0.8912
# Epoch 14/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.2141 - accuracy: 0.9183 - val_loss: 0.3815 - val_accuracy: 0.8906
# Epoch 15/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.2044 - accuracy: 0.9230 - val_loss: 0.4193 - val_accuracy: 0.8848
# Epoch 16/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1954 - accuracy: 0.9269 - val_loss: 0.3998 - val_accuracy: 0.8886
# Epoch 17/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1946 - accuracy: 0.9254 - val_loss: 0.4539 - val_accuracy: 0.8907
# Epoch 18/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1870 - accuracy: 0.9294 - val_loss: 0.4876 - val_accuracy: 0.8842
# Epoch 19/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1828 - accuracy: 0.9305 - val_loss: 0.4029 - val_accuracy: 0.8925
# Epoch 20/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1835 - accuracy: 0.9317 - val_loss: 0.3969 - val_accuracy: 0.8909
# Epoch 21/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1744 - accuracy: 0.9333 - val_loss: 0.4349 - val_accuracy: 0.8853
# Epoch 22/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1704 - accuracy: 0.9354 - val_loss: 0.4398 - val_accuracy: 0.8911
# Epoch 23/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1669 - accuracy: 0.9367 - val_loss: 0.4414 - val_accuracy: 0.8957
# Epoch 24/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1635 - accuracy: 0.9396 - val_loss: 0.4703 - val_accuracy: 0.8883
# Epoch 25/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.1576 - accuracy: 0.9409 - val_loss: 0.4794 - val_accuracy: 0.8910
# Epoch 26/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1575 - accuracy: 0.9418 - val_loss: 0.4323 - val_accuracy: 0.8925
# Epoch 27/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1569 - accuracy: 0.9416 - val_loss: 0.4285 - val_accuracy: 0.8959
# Epoch 28/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1529 - accuracy: 0.9427 - val_loss: 0.5074 - val_accuracy: 0.8893
# Epoch 29/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1487 - accuracy: 0.9453 - val_loss: 0.5045 - val_accuracy: 0.8896
# Epoch 30/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1501 - accuracy: 0.9445 - val_loss: 0.5169 - val_accuracy: 0.8907
# Epoch 31/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1454 - accuracy: 0.9442 - val_loss: 0.4856 - val_accuracy: 0.8937
# Epoch 32/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1457 - accuracy: 0.9455 - val_loss: 0.4746 - val_accuracy: 0.8950
# Epoch 33/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.1409 - accuracy: 0.9484 - val_loss: 0.6006 - val_accuracy: 0.8883
# Epoch 34/100
# 60000/60000 [==============================] - 11s 186us/sample - loss: 0.1371 - accuracy: 0.9483 - val_loss: 0.5189 - val_accuracy: 0.8899
# Epoch 35/100
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.1347 - accuracy: 0.9495 - val_loss: 0.5137 - val_accuracy: 0.8900
# Epoch 36/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.1370 - accuracy: 0.9500 - val_loss: 0.5274 - val_accuracy: 0.8929
# Epoch 37/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.1331 - accuracy: 0.9513 - val_loss: 0.5489 - val_accuracy: 0.8936
# Epoch 38/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.1314 - accuracy: 0.9515 - val_loss: 0.5652 - val_accuracy: 0.8943
# Epoch 39/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.1294 - accuracy: 0.9527 - val_loss: 0.6209 - val_accuracy: 0.8928
# Epoch 40/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.1277 - accuracy: 0.9532 - val_loss: 0.5607 - val_accuracy: 0.8893
# Epoch 41/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.1258 - accuracy: 0.9542 - val_loss: 0.6241 - val_accuracy: 0.8928
# Epoch 42/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.1232 - accuracy: 0.9551 - val_loss: 0.5316 - val_accuracy: 0.8950
# Epoch 43/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1223 - accuracy: 0.9560 - val_loss: 0.7004 - val_accuracy: 0.8932
# Epoch 44/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1221 - accuracy: 0.9562 - val_loss: 0.6698 - val_accuracy: 0.8882
# Epoch 45/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1219 - accuracy: 0.9564 - val_loss: 0.7354 - val_accuracy: 0.8895
# Epoch 46/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1199 - accuracy: 0.9569 - val_loss: 0.5233 - val_accuracy: 0.8943
# Epoch 47/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1168 - accuracy: 0.9584 - val_loss: 0.6794 - val_accuracy: 0.8917
# Epoch 48/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1178 - accuracy: 0.9584 - val_loss: 0.7477 - val_accuracy: 0.8876
# Epoch 49/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1129 - accuracy: 0.9590 - val_loss: 0.7359 - val_accuracy: 0.8891
# Epoch 50/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1132 - accuracy: 0.9593 - val_loss: 0.7084 - val_accuracy: 0.8915
# Epoch 51/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1116 - accuracy: 0.9609 - val_loss: 1.0561 - val_accuracy: 0.8839
# Epoch 52/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1089 - accuracy: 0.9608 - val_loss: 0.7387 - val_accuracy: 0.8873
# Epoch 53/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1118 - accuracy: 0.9607 - val_loss: 0.8479 - val_accuracy: 0.8921
# Epoch 54/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.1077 - accuracy: 0.9609 - val_loss: 0.8166 - val_accuracy: 0.8909
# Epoch 55/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1076 - accuracy: 0.9624 - val_loss: 0.9971 - val_accuracy: 0.8912
# Epoch 56/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.1035 - accuracy: 0.9634 - val_loss: 0.8481 - val_accuracy: 0.8898
# Epoch 57/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1047 - accuracy: 0.9626 - val_loss: 0.7715 - val_accuracy: 0.8872
# Epoch 58/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1037 - accuracy: 0.9633 - val_loss: 1.2427 - val_accuracy: 0.8893
# Epoch 59/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1072 - accuracy: 0.9629 - val_loss: 1.0527 - val_accuracy: 0.8883
# Epoch 60/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.1082 - accuracy: 0.9618 - val_loss: 1.0714 - val_accuracy: 0.8896
# Epoch 61/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0989 - accuracy: 0.9654 - val_loss: 0.9304 - val_accuracy: 0.8911
# Epoch 62/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0964 - accuracy: 0.9655 - val_loss: 0.9889 - val_accuracy: 0.8890
# Epoch 63/100
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.1046 - accuracy: 0.9647 - val_loss: 1.0382 - val_accuracy: 0.8939
# Epoch 64/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0982 - accuracy: 0.9660 - val_loss: 1.2244 - val_accuracy: 0.8935
# Epoch 65/100
# 60000/60000 [==============================] - 11s 185us/sample - loss: 0.0980 - accuracy: 0.9658 - val_loss: 1.0039 - val_accuracy: 0.8855
# Epoch 66/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.1001 - accuracy: 0.9661 - val_loss: 1.0707 - val_accuracy: 0.8860
# Epoch 67/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0961 - accuracy: 0.9674 - val_loss: 0.8381 - val_accuracy: 0.8874
# Epoch 68/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0936 - accuracy: 0.9670 - val_loss: 0.8668 - val_accuracy: 0.8919
# Epoch 69/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0982 - accuracy: 0.9672 - val_loss: 1.6491 - val_accuracy: 0.8875
# Epoch 70/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0970 - accuracy: 0.9664 - val_loss: 0.8566 - val_accuracy: 0.8886
# Epoch 71/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0929 - accuracy: 0.9684 - val_loss: 0.8912 - val_accuracy: 0.8905
# Epoch 72/100
# 60000/60000 [==============================] - 11s 182us/sample - loss: 0.0923 - accuracy: 0.9678 - val_loss: 1.1076 - val_accuracy: 0.8889
# Epoch 73/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0982 - accuracy: 0.9670 - val_loss: 1.0379 - val_accuracy: 0.8902
# Epoch 74/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0916 - accuracy: 0.9689 - val_loss: 3.4692 - val_accuracy: 0.8862
# Epoch 75/100
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.0954 - accuracy: 0.9679 - val_loss: 4.0519 - val_accuracy: 0.8949
# Epoch 76/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0914 - accuracy: 0.9689 - val_loss: 1.4574 - val_accuracy: 0.8895
# Epoch 77/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0893 - accuracy: 0.9696 - val_loss: 7.0528 - val_accuracy: 0.8914
# Epoch 78/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0918 - accuracy: 0.9686 - val_loss: 2.1946 - val_accuracy: 0.8879
# Epoch 79/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0896 - accuracy: 0.9687 - val_loss: 0.8611 - val_accuracy: 0.8882
# Epoch 80/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0943 - accuracy: 0.9687 - val_loss: 3.6521 - val_accuracy: 0.8888
# Epoch 81/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0871 - accuracy: 0.9706 - val_loss: 1.0936 - val_accuracy: 0.8889
# Epoch 82/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0920 - accuracy: 0.9693 - val_loss: 2.0849 - val_accuracy: 0.8891
# Epoch 83/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0883 - accuracy: 0.9703 - val_loss: 1.2606 - val_accuracy: 0.8870
# Epoch 84/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0839 - accuracy: 0.9706 - val_loss: 2.1532 - val_accuracy: 0.8827
# Epoch 85/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0893 - accuracy: 0.9695 - val_loss: 3.0220 - val_accuracy: 0.8926
# Epoch 86/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0914 - accuracy: 0.9697 - val_loss: 1.6212 - val_accuracy: 0.8900
# Epoch 87/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0884 - accuracy: 0.9706 - val_loss: 1.4705 - val_accuracy: 0.8895
# Epoch 88/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0904 - accuracy: 0.9709 - val_loss: 23.9947 - val_accuracy: 0.8902
# Epoch 89/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0866 - accuracy: 0.9710 - val_loss: 1.4313 - val_accuracy: 0.8896
# Epoch 90/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0843 - accuracy: 0.9729 - val_loss: 3.8291 - val_accuracy: 0.8917
# Epoch 91/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0876 - accuracy: 0.9706 - val_loss: 0.9566 - val_accuracy: 0.8876
# Epoch 92/100
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.0824 - accuracy: 0.9723 - val_loss: 1.0827 - val_accuracy: 0.8889
# Epoch 93/100
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.0816 - accuracy: 0.9729 - val_loss: 1.1187 - val_accuracy: 0.8904
# Epoch 94/100
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.0849 - accuracy: 0.9725 - val_loss: 2.5691 - val_accuracy: 0.8905
# Epoch 95/100
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.0790 - accuracy: 0.9735 - val_loss: 2.2603 - val_accuracy: 0.8904
# Epoch 96/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0852 - accuracy: 0.9714 - val_loss: 2.4223 - val_accuracy: 0.8913
# Epoch 97/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0820 - accuracy: 0.9737 - val_loss: 1.3322 - val_accuracy: 0.8936
# Epoch 98/100
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.0835 - accuracy: 0.9725 - val_loss: 2.5798 - val_accuracy: 0.8947
# Epoch 99/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0865 - accuracy: 0.9718 - val_loss: 5.8796 - val_accuracy: 0.8922
# Epoch 100/100
# 60000/60000 [==============================] - 11s 177us/sample - loss: 0.0809 - accuracy: 0.9734 - val_loss: 2.3221 - val_accuracy: 0.8842

# %%
# After 100 epochs the loss occilated around 0.45, with a validation accuracy around 88%.
